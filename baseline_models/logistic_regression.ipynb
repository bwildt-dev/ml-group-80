# %% [markdown]
# # Logistic Regression - Likelihood to Smoke
# This notebook serves as an indicator for the baseline performance of the dataset currently used.

# %% [markdown]
# ## Imports

# %%
from sklearn.linear_model import LogisticRegression
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    confusion_matrix,
    roc_curve,
    RocCurveDisplay
)

# %% [markdown]
# ## Initiation

# %%
model = LogisticRegression()

#Importing training set
X_train = pd.read_csv("../data/trainX.csv")
y_train = pd.read_csv("../data/trainY.csv")

#Importing validation set
X_valid = pd.read_csv("../data/validX.csv")
y_valid = pd.read_csv("../data/validY.csv")

# %%
X_train.head()
# Out:
#           0         1         2         3         4
# 0  0.607143  0.509804  0.633803  0.660377  0.515873
# 1  0.404762  0.803921  0.563380  0.594340  0.373016
# 2  0.535714  0.607843  0.563380  0.437107  0.214286
# 3  0.654762  0.901961  0.915493  0.242138  0.341270
# 4  0.428571  0.705882  0.915493  0.292453  0.682540

# %% [markdown]
# ## Model Training

# %%
model.fit(X_train, np.ravel(y_train, order='C'))
# Out:
# LogisticRegression()

# %% [markdown]
# ## Evaluation

# %%
y_pred = model.predict(X_valid)
acc = accuracy_score(y_pred, y_valid)
f1 = f1_score(y_pred, y_valid, average='binary')

print("Accuracy:", acc)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.739799921537858
# F1 Score: 0.7016978374123909

# %% [markdown]
# ### Confusion Matrix

# %%
cm = confusion_matrix(y_valid, y_pred, labels=model.classes_)
matrix_plot = sns.heatmap(cm, annot=True, fmt="d", cmap="ocean")

matrix_plot.set_title("Confusion Matrix for Logistic Regression")
matrix_plot.set_xlabel("Predicted Smoker", fontsize=14, labelpad=20)
matrix_plot.xaxis.set_ticklabels(['Negative', 'Positive'])

matrix_plot.set_ylabel("Actual Smoker", fontsize=14, labelpad=20)
matrix_plot.yaxis.set_ticklabels(['Negative', 'Positive'])

plt.show()

# %% [markdown]
# ### ROC-curve

# %%
y_proba = model.predict_proba(X_valid)

fpr, tpr, _ = roc_curve(y_valid, y_proba[:, 1])
roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr).plot()
roc_display.figure_.set_size_inches(5,5)
plt.plot([0, 1], [0, 1], color = 'g')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
